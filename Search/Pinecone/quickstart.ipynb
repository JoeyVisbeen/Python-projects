# %% [markdown]
# # 🌲  Pinecone quickstart
#
# Author: J Visbeen
# Target: Practice
# Main source: https://github.com/pinecone-io/examples/blob/master/learn/search/hybrid-search/ecommerce-search/ecommerce-search.ipynb

# %%
from pinecone import Pinecone, ServerlessSpec
from dotenv import load_dotenv
import os
load_dotenv()

pinecone = Pinecone(api_key=os.getenv('PINECONE_API'))
index = pinecone.Index('amazonproducts')
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %% [markdown]
# Create index only if not already exist. I found it easier to make one through the UI.

# %%
'''
pinecone.create_index(
    name='amazonproducts',
    dimension=8,
    metric='cosine',
    spec=ServerlessSpec(
        cloud='GCP',
        region='us-central1-gcp'
    )
)
'''

# %% [markdown]
# Prep dataset

# %%
import pandas as pd

df_categories = (
    pd.read_csv('../amazon_categories.csv')
    .dropna()
    .reset_index()
)

df_products = (
    pd.read_csv('../amazon_products.csv')
    .dropna()
    .sample(1000000)
    .reset_index()
)
pd.read_excel('').dropna()
merged_df = pd.merge(df_products, df_categories, left_on='category_id', right_on='id', how='left')
merged_df.drop('category_id', axis=1)
merged_df['title']
# Out:
# 0         mDesign Large Metal Farmhouse Storage Organize...
# 1         Vegan Premium Canvas Fanny Pack Diaper Bag: Wi...
# 2         100+PCS Technic Gears and Axles Compatible wit...
# 3         Girl's Graphic Print Long Sleeve Sweatshirt To...
# 4         Women Boho Handmade Natural Stone Crystal Leat...
#                                 ...
# 999995    Saucer Swing for Kids, 45 Inch Swing Chair, Ou...
# 999996    LED Strobe Beacon Lights 12V Amber Flashing Wa...
# 999997    Dust Free Hamster Bath Sand/Natural Cleansing ...
# 999998    Fast Wall Charger 5FT Charging Cable Cord fit ...
# 999999    to My Son Pocket Hug Token with Leather Keycha...
# Name: title, Length: 1000000, dtype: object

# %% [markdown]
# Train BM25 encoder.

# %%
from pinecone_text.sparse import BM25Encoder

t_set = merged_df['title'].tolist()
bm25 = BM25Encoder()
bm25.fit(t_set)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
bm25.encode_documents(merged_df['title'].tolist()[0])
# Out:
# {'indices': [207125060,
#   2177509083,
#   3594301313,
#   2654641506,
#   1119423170,
#   3337197764,
#   1516167604,
#   805888890,
#   2357056077,
#   1027044273,
#   1579027372,
#   693667937,
#   2626449335,
#   91242678,
#   2361787631,
#   3033147134,
#   869237476,
#   303109060,
#   2784200036,
#   1014127006,
#   19522071,
#   453650801,
#   1043209972],
#  'values': [0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.554981847820371,
#   0.38406565826405037,
#   0.554981847820371,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037,
#   0.38406565826405037]}

# %% [markdown]
# Test sentence transformer

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# %%
meta = merged_df[:1000:]
db_sample_set = meta['title'].tolist()
dense_vec = model.encode(db_sample_set[0])

# %%
meta.iloc[1]
# Out:
# index_x                                                        1209568
# asin                                                        B0C762Z1F5
# title                Vegan Premium Canvas Fanny Pack Diaper Bag: Wi...
# imgUrl               https://m.media-amazon.com/images/I/61wzaz-+mj...
# productURL                        https://www.amazon.com/dp/B0C762Z1F5
# stars                                                              4.6
# reviews                                                              0
# price                                                             89.0
# listPrice                                                          0.0
# category_id                                                         36
# isBestSeller                                                     False
# boughtInLastMonth                                                    0
# index_y                                                             35
# id                                                                  36
# category_name                                         Baby Travel Gear
# Name: 1, dtype: object

# %% [markdown]
# Encode data and upsert data

# %%
from tqdm.auto import tqdm

upserts = []
i = 0
for item in tqdm(range(0, len(db_sample_set))):
    upserts.append({
        'id': str(i),
        'sparse_values': bm25.encode_documents(db_sample_set[i]),
        'values': model.encode(db_sample_set[i]).tolist(),
        'metadata': meta.iloc[i].to_dict()
    })
    i+=1

index.upsert(upserts)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# {'upserted_count': 1000}

# %% [markdown]
# Query the data

# %%
query = 'Beautiful flowers for in the garden'

sparse = bm25.encode_queries(query)
dense = model.encode(query).tolist()

result = index.query(
    top_k=20,
    vector=dense,
    sparse_vector=sparse,
    include_metadata=True
)
result
# Out:
# {'matches': [{'id': '209',
#               'metadata': {'asin': 'B096FFCYCJ',
#                            'boughtInLastMonth': 400.0,
#                            'category_id': 163.0,
#                            'category_name': 'Bath Products',
#                            'id': 163.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/71XV0KDDa-S._AC_UL320_.jpg',
#                            'index_x': 388935.0,
#                            'index_y': 149.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 19.99,
#                            'productURL': 'https://www.amazon.com/dp/B096FFCYCJ',
#                            'reviews': 0.0,
#                            'stars': 4.6,
#                            'title': 'Rustic Farmhouse Shower Curtain, Farm '
#                                     'Teal Daisy Floral Flowers and Butterfly '
#                                     'on Country Wooden Shower Curtain for '
#                                     'Bathroom, Turquoise Blue with 12PCS '
#                                     'Hooks, 70X70IN'},
#               'score': 0.650839448,
#               'values': []},
#              {'id': '662',
#               'metadata': {'asin': 'B0C2ZFRLXP',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 95.0,
#                            'category_name': "Girls' Jewelry",
#                            'id': 95.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/71JszYiqNiL._AC_UL320_.jpg',
#                            'index_x': 207759.0,
#                            'index_y': 85.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 8.5,
#                            'productURL': 'https://www.amazon.com/dp/B0C2ZFRLXP',
#                            'reviews': 3.0,
#                            'stars': 4.6,
#                            'title': 'Vintage Daisy Flower Dangle Drop Earrings '
#                                     'Little Daisy Hoop Huggie Earrings Flower '
#                                     'Daisy Earrings Gold Minimal Earrings '
#                                     'Jewelry for Women and Girls'},
#               'score': 0.602105498,
#               'values': []},
#              {'id': '953',
#               'metadata': {'asin': 'B0CCJS3YHF',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 88.0,
#                            'category_name': "Boys' Jewelry",
#                            'id': 88.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/21LhIjGxdXL._AC_UL320_.jpg',
#                            'index_x': 706316.0,
#                            'index_y': 80.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 7.0,
#                            'productURL': 'https://www.amazon.com/dp/B0CCJS3YHF',
#                            'reviews': 0.0,
#                            'stars': 0.0,
#                            'title': 'White Flower and Yellow Moti Designer '
#                                     'Thread Based Rakhi For Boys,Girls,Men & '
#                                     'Women [Pack Of 2] Made In India'},
#               'score': 0.561384082,
#               'values': []},
#              {'id': '326',
#               'metadata': {'asin': 'B072KDDSGK',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 35.0,
#                            'category_name': 'Baby Care Products',
#                            'id': 35.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/51VPVuz0m-L._AC_UL320_.jpg',
#                            'index_x': 305154.0,
#                            'index_y': 34.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 6.99,
#                            'productURL': 'https://www.amazon.com/dp/B072KDDSGK',
#                            'reviews': 584.0,
#                            'stars': 4.6,
#                            'title': 'Floral Fall Baby Girls Cute Elastic '
#                                     'Chiffon Lace flower Headbands Hair Bands '
#                                     'BY-36 (White)'},
#               'score': 0.560296834,
#               'values': []},
#              {'id': '420',
#               'metadata': {'asin': 'B0C69CTW2L',
#                            'boughtInLastMonth': 200.0,
#                            'category_id': 174.0,
#                            'category_name': 'Wall Art',
#                            'id': 174.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/71ODQZXCS3L._AC_UL320_.jpg',
#                            'index_x': 448091.0,
#                            'index_y': 160.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 16.99,
#                            'productURL': 'https://www.amazon.com/dp/B0C69CTW2L',
#                            'reviews': 0.0,
#                            'stars': 4.4,
#                            'title': 'Vintage Wall Art Aesthetic Farmhouse Wall '
#                                     'Decor Flower Boho Canvas Wall Art Prints '
#                                     'Rustic Wall Decor for Bedroom Living Room '
#                                     'Bathroom Nature Jasmine Fruit Tree Sea '
#                                     'Grassland Pictures,UNFRAMED（Floral,9pcs)'},
#               'score': 0.542124,
#               'values': []},
#              {'id': '429',
#               'metadata': {'asin': 'B074DXT94M',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 8.0,
#                            'category_name': 'Needlework Supplies',
#                            'id': 8.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/81SUpLZbm8L._AC_UL320_.jpg',
#                            'index_x': 473029.0,
#                            'index_y': 7.0,
#                            'isBestSeller': False,
#                            'listPrice': 44.14,
#                            'price': 39.19,
#                            'productURL': 'https://www.amazon.com/dp/B074DXT94M',
#                            'reviews': 0.0,
#                            'stars': 4.7,
#                            'title': 'Bothy Threads Counted Cross Stitch Kit - '
#                                     'William Morris Bell Flower'},
#               'score': 0.482036591,
#               'values': []},
#              {'id': '438',
#               'metadata': {'asin': 'B01N35VMYK',
#                            'boughtInLastMonth': 100.0,
#                            'category_id': 225.0,
#                            'category_name': "Kids' Dress Up & Pretend Play",
#                            'id': 225.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/71XcozNV0JL._AC_UL320_.jpg',
#                            'index_x': 499485.0,
#                            'index_y': 210.0,
#                            'isBestSeller': False,
#                            'listPrice': 27.99,
#                            'price': 24.99,
#                            'productURL': 'https://www.amazon.com/dp/B01N35VMYK',
#                            'reviews': 0.0,
#                            'stars': 4.6,
#                            'title': 'Oojami Plastic Lei Assortment (100 Piece '
#                                     'Pack) Colorful Fun Vibrant Flower Lei '
#                                     'Necklaces - 100 pc Assortment Pack '
#                                     'Perfect for Hawaiian Themed Parties'},
#               'score': 0.478820562,
#               'values': []},
#              {'id': '160',
#               'metadata': {'asin': 'B07SPW68DF',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 124.0,
#                            'category_name': "Kids' Furniture",
#                            'id': 124.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/81gAaALvppL._AC_UL320_.jpg',
#                            'index_x': 162940.0,
#                            'index_y': 110.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 39.99,
#                            'productURL': 'https://www.amazon.com/dp/B07SPW68DF',
#                            'reviews': 145.0,
#                            'stars': 4.0,
#                            'title': 'Sweet Jojo Designs Pink and Grey Rose '
#                                     'Flower Girl Baby Nursery or Kids Room '
#                                     'Small Fabric Toy Bin Storage Box Chest '
#                                     'for Watercolor Floral Collection'},
#               'score': 0.478296548,
#               'values': []},
#              {'id': '483',
#               'metadata': {'asin': 'B093WFVXYW',
#                            'boughtInLastMonth': 50.0,
#                            'category_id': 51.0,
#                            'category_name': 'Foot, Hand & Nail Care Products',
#                            'id': 51.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/71odau5xzrL._AC_UL320_.jpg',
#                            'index_x': 261181.0,
#                            'index_y': 49.0,
#                            'isBestSeller': False,
#                            'listPrice': 7.99,
#                            'price': 6.99,
#                            'productURL': 'https://www.amazon.com/dp/B093WFVXYW',
#                            'reviews': 11.0,
#                            'stars': 3.6,
#                            'title': 'Diasy Nail Art Charms 60 PCS Flower Nail '
#                                     'Art Decal Colorful Daisy Blossom Designs '
#                                     'Decoration Resin Nail Art Jewelry for '
#                                     'Women DIY Manicure Tips'},
#               'score': 0.464072138,
#               'values': []},
#              {'id': '888',
#               'metadata': {'asin': 'B0BR4BJNYK',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 209.0,
#                            'category_name': 'Lighting & Ceiling Fans',
#                            'id': 209.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/71tNrA6HiDL._AC_UL320_.jpg',
#                            'index_x': 435852.0,
#                            'index_y': 194.0,
#                            'isBestSeller': False,
#                            'listPrice': 49.99,
#                            'price': 29.99,
#                            'productURL': 'https://www.amazon.com/dp/B0BR4BJNYK',
#                            'reviews': 0.0,
#                            'stars': 4.4,
#                            'title': '4 Pack Solar Garden Lights, New Upgraded '
#                                     '8 LED Firefly Waterproof Solar Powered '
#                                     'High Flexibility Swaying Outdoor Lights '
#                                     'for Pathway Yard Walkway Patio '
#                                     'Decoration, Warm White'},
#               'score': 0.458782554,
#               'values': []},
#              {'id': '644',
#               'metadata': {'asin': 'B08JLXP9YP',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 91.0,
#                            'category_name': "Girls' Clothing",
#                            'id': 91.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/61tVPBcZ6GL._MCnd_AC_UL320_.jpg',
#                            'index_x': 79247.0,
#                            'index_y': 83.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 57.99,
#                            'productURL': 'https://www.amazon.com/dp/B08JLXP9YP',
#                            'reviews': 1011.0,
#                            'stars': 4.3,
#                            'title': 'Girls Princess Tulle Lace Flower Pageant '
#                                     'Dress Puffy Floor Length Wedding '
#                                     'Bridesmaid Dress Party Tutu Maxi Gown'},
#               'score': 0.45526877,
#               'values': []},
#              {'id': '283',
#               'metadata': {'asin': 'B07XFGQMW5',
#                            'boughtInLastMonth': 200.0,
#                            'category_id': 12.0,
#                            'category_name': 'Gift Wrapping Supplies',
#                            'id': 12.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/713Pvt+jB8L._AC_UL320_.jpg',
#                            'index_x': 502611.0,
#                            'index_y': 11.0,
#                            'isBestSeller': False,
#                            'listPrice': 11.99,
#                            'price': 8.69,
#                            'productURL': 'https://www.amazon.com/dp/B07XFGQMW5',
#                            'reviews': 0.0,
#                            'stars': 4.7,
#                            'title': 'Light Up Glowing Gift Bows, 6 Iridescent '
#                                     'LED Ribbon Bow for Gift Packaging and '
#                                     'Decorations- LED Glowing Gift Ribbon '
#                                     'Flower Bows, Self Adhesive'},
#               'score': 0.43339777,
#               'values': []},
#              {'id': '133',
#               'metadata': {'asin': 'B0BQM8KR4G',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 91.0,
#                            'category_name': "Girls' Clothing",
#                            'id': 91.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/51kl0rqA5qL._MCnd_AC_UL320_.jpg',
#                            'index_x': 510470.0,
#                            'index_y': 83.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 39.99,
#                            'productURL': 'https://www.amazon.com/dp/B0BQM8KR4G',
#                            'reviews': 0.0,
#                            'stars': 4.6,
#                            'title': 'Crossed Straps Flower Girl Dress Satin '
#                                     'Long Prom Dress with Bow Puffy Tulle '
#                                     'Pageant Dresses for Girls'},
#               'score': 0.42112869,
#               'values': []},
#              {'id': '48',
#               'metadata': {'asin': 'B0BYVJVS8P',
#                            'boughtInLastMonth': 100.0,
#                            'category_id': 110.0,
#                            'category_name': "Men's Clothing",
#                            'id': 110.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/71ZKjb3ssRL._AC_UL320_.jpg',
#                            'index_x': 4738.0,
#                            'index_y': 100.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 25.99,
#                            'productURL': 'https://www.amazon.com/dp/B0BYVJVS8P',
#                            'reviews': 0.0,
#                            'stars': 4.5,
#                            'title': "Men's Flower Casual Short Sleeve Aloha "
#                                     'Hawaiian Shirt'},
#               'score': 0.358662248,
#               'values': []},
#              {'id': '761',
#               'metadata': {'asin': 'B089YGH6FX',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 94.0,
#                            'category_name': "Girls' Accessories",
#                            'id': 94.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/713KnMuUiPL._AC_UL320_.jpg',
#                            'index_x': 1324650.0,
#                            'index_y': 84.0,
#                            'isBestSeller': False,
#                            'listPrice': 11.99,
#                            'price': 9.99,
#                            'productURL': 'https://www.amazon.com/dp/B089YGH6FX',
#                            'reviews': 0.0,
#                            'stars': 4.8,
#                            'title': '4 Pairs Kids Flower Shaped Sunglasses '
#                                     'Round with 4 Pack Glasses Cloth 4 Pack '
#                                     'Flannel Bag for Toddler Baby Girls Boys '
#                                     'Party Favor'},
#               'score': 0.348169386,
#               'values': []},
#              {'id': '681',
#               'metadata': {'asin': 'B0931ZRKCL',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 3.0,
#                            'category_name': 'Knitting & Crochet Supplies',
#                            'id': 3.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/81WFBdHKhFS._AC_UL320_.jpg',
#                            'index_x': 839927.0,
#                            'index_y': 2.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 7.99,
#                            'productURL': 'https://www.amazon.com/dp/B0931ZRKCL',
#                            'reviews': 0.0,
#                            'stars': 4.2,
#                            'title': 'Ice Yarns Picasso Blues, Lilac, Grape, '
#                                     'Purple Fuzzy with Subtle Sheen Yarn, '
#                                     'Polyester, Acrylic Blend 50 Gram 125 '
#                                     'Yards'},
#               'score': 0.341626436,
#               'values': []},
#              {'id': '621',
#               'metadata': {'asin': 'B09CGPGNH6',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 141.0,
#                            'category_name': 'Industrial Hardware',
#                            'id': 141.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/91-E3SfW5iL._AC_UL320_.jpg',
#                            'index_x': 279836.0,
#                            'index_y': 127.0,
#                            'isBestSeller': False,
#                            'listPrice': 11.98,
#                            'price': 10.99,
#                            'productURL': 'https://www.amazon.com/dp/B09CGPGNH6',
#                            'reviews': 28.0,
#                            'stars': 4.3,
#                            'title': 'Gransuncy 100 Pieces of S Shaped Metal '
#                                     'Hooks Clip, S Shaped Hooks Hanging '
#                                     'Hangers Hooks for Bathroom, Kitchen, Work '
#                                     'Shop, Garden'},
#               'score': 0.341339946,
#               'values': []},
#              {'id': '348',
#               'metadata': {'asin': 'B0BK6SSKFJ',
#                            'boughtInLastMonth': 100.0,
#                            'category_id': 11.0,
#                            'category_name': 'Craft Supplies & Materials',
#                            'id': 11.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/91JnVOm7UEL._AC_UL320_.jpg',
#                            'index_x': 1289737.0,
#                            'index_y': 10.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 6.29,
#                            'productURL': 'https://www.amazon.com/dp/B0BK6SSKFJ',
#                            'reviews': 0.0,
#                            'stars': 4.6,
#                            'title': '360pcs Colorful Feathers 3-5 inch Craft '
#                                     'Feathers Assorted Rainbow Colors Feathers '
#                                     'for Kids for DIY Handmade Wedding Home '
#                                     'Party Decorations Natural Feather'},
#               'score': 0.332713306,
#               'values': []},
#              {'id': '804',
#               'metadata': {'asin': 'B07K7WGTZY',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 209.0,
#                            'category_name': 'Lighting & Ceiling Fans',
#                            'id': 209.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/61f4YqlRuJL._AC_UL320_.jpg',
#                            'index_x': 443981.0,
#                            'index_y': 194.0,
#                            'isBestSeller': False,
#                            'listPrice': 34.99,
#                            'price': 29.42,
#                            'productURL': 'https://www.amazon.com/dp/B07K7WGTZY',
#                            'reviews': 0.0,
#                            'stars': 4.2,
#                            'title': 'Home Zone Security 4 Packs Solar Deck '
#                                     'Light Outdoor 20 Lumens Waterproof '
#                                     'Weather Resistant, No Wiring, Auto On '
#                                     'Sensor Fence Light, Durable Aluminum '
#                                     'Plastic Case for Decor Step Pathway '
#                                     'Backyard Garden'},
#               'score': 0.318570614,
#               'values': []},
#              {'id': '103',
#               'metadata': {'asin': 'B0BHVW2J49',
#                            'boughtInLastMonth': 0.0,
#                            'category_id': 95.0,
#                            'category_name': "Girls' Jewelry",
#                            'id': 95.0,
#                            'imgUrl': 'https://m.media-amazon.com/images/I/51nsxAb1FxL._AC_UL320_.jpg',
#                            'index_x': 214189.0,
#                            'index_y': 85.0,
#                            'isBestSeller': False,
#                            'listPrice': 0.0,
#                            'price': 12.99,
#                            'productURL': 'https://www.amazon.com/dp/B0BHVW2J49',
#                            'reviews': 59.0,
#                            'stars': 4.3,
#                            'title': 'Charm 925 Sterling Silver Pendant,Girl '
#                                     'Jewelry Beads Gifts for Women '
#                                     'Bracelet&Necklace'},
#               'score': 0.297607392,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 7}}

# %%
def hybrid_scale(dense_query, sparse_query, alpha: float):
    
    if alpha < 0 or alpha > 1:
        raise ValueError("aplha needs to be between 1 or 0")
    hsparse = {
        'indices': sparse_query['indices'],
        'values':  [v * (1.0 - alpha) for v in sparse_query['values']]
    }
    hdense = []
    for i in dense_query:
        for j in i:
            hdense.append(dense_query[i][j] * alpha)
    
    hdense = [v * alpha for v in dense_query]
    
    return hdense, hsparse

# %%
def hybrid_query(query: str, top_k: int, alpha: float):
    sparse_vec = bm25.encode_queries(query)
    dense_vec = model.encode([query]).tolist()

    dense_vec, sparse_vec = hybrid_scale(
        sparse_query=sparse_vec,
        dense_query=dense_vec,
        alpha=alpha)
    
    result = index.query(
        vector=dense_vec,
        sparse_vector=sparse_vec,
        top_k=top_k,
        include_metadata=True
    )

    return result

# %%
hybrid_query('Shooter games for kids', 10, 0.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 hybrid_query('Shooter games for kids', 10, 0.3)
#
# Cell In[156], line 5, in hybrid_query(query, top_k, alpha)
#       2 sparse_vec = bm25.encode_queries(query)
#       3 dense_vec = model.encode([query]).tolist()
# ----> 5 dense_vec, sparse_vec = hybrid_scale(
#       6     sparse_query=sparse_vec,
#       7     dense_query=dense_vec,
#       8     alpha=alpha)
#      10 result = index.query(
#      11     vector=dense_vec,
#      12     sparse_vector=sparse_vec,
#      13     top_k=top_k,
#      14     include_metadata=True
#      15 )
#      17 return result
#
# Cell In[155], line 12, in hybrid_scale(dense_query, sparse_query, alpha)
#      10 for i in dense_query:
#      11     for j in i:
# ---> 12         hdense.append(dense_query[i][j] * alpha)
#      14 #hdense = [v * alpha for v in dense_query]
#      16 return hdense, hsparse
#
# TypeError: list indices must be integers or slices, not list
