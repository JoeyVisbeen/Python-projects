# %%
from pysolr import Solr
import json
solr_url = 'http://localhost:8983/solr//'
solr = Solr(solr_url)

# %%
response = solr.ping()
response
# Out:
# '{\n  "responseHeader":{\n    "zkConnected":null,\n    "status":0,\n    "QTime":0,\n    "params":{\n      "q":"{!lucene}*:*",\n      "distrib":"false",\n      "df":"text",\n      "rows":"10",\n      "echoParams":"all",\n      "rid":"localhost-173"\n    }\n  },\n  "status":"OK"\n}'

# %%
import pandas as pd

df = (
    pd.read_csv('../amazon_products_100000.csv')
    .dropna()
    .reset_index()
)
df
# Out:
#       index        asin                                              title  \
# 0         0  B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1         1  B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2         2  B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3         3  B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4         4  B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
# ...     ...         ...                                                ...
# 9995   9995  B0BR617B8P  Mens Athletic Workout Shorts with Compression ...
# 9996   9996  B07VWSP5HD  Men's Knitted Regular Fit Full Zip Cardigan Sw...
# 9997   9997  B0CD6MBV8T  Men's Jacket Windproof Qulited Bomber Jackets ...
# 9998   9998  B08XW98F22                           Men's Dry Franchise Polo
# 9999   9999  B077SN37K5     Men’s Athletic Sock 8-pair, White (White, 13+)
#
#                                                  imgUrl  \
# 0     https://m.media-amazon.com/images/I/815dLQKYIY...
# 1     https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2     https://m.media-amazon.com/images/I/71EA35zvJB...
# 3     https://m.media-amazon.com/images/I/91k6NYLQyI...
# 4     https://m.media-amazon.com/images/I/61NJoaZcP9...
# ...                                                 ...
# 9995  https://m.media-amazon.com/images/I/61MFjWYxa5...
# 9996  https://m.media-amazon.com/images/I/91Hm4RVlu8...
# 9997  https://m.media-amazon.com/images/I/61sVoWGbg3...
# 9998  https://m.media-amazon.com/images/I/51yJ8ZYPcs...
# 9999  https://m.media-amazon.com/images/I/61R4-uAH97...
#
#                                 productURL  stars  reviews   price  listPrice  \
# 0     https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99       0.00
# 1     https://www.amazon.com/dp/B07GDLCQXV    4.5        0  169.99     209.99
# 2     https://www.amazon.com/dp/B07XSCCZYG    4.6        0  365.49     429.99
# 3     https://www.amazon.com/dp/B08MVFKGJM    4.6        0  291.59     354.37
# 4     https://www.amazon.com/dp/B01DJLKZBA    4.5        0  174.99     309.99
# ...                                    ...    ...      ...     ...        ...
# 9995  https://www.amazon.com/dp/B0BR617B8P    4.5        0   34.99       0.00
# 9996  https://www.amazon.com/dp/B07VWSP5HD    4.4        0   49.99      59.99
# 9997  https://www.amazon.com/dp/B0CD6MBV8T    4.6        0   46.98       0.00
# 9998  https://www.amazon.com/dp/B08XW98F22    4.4        0   46.87      55.00
# 9999  https://www.amazon.com/dp/B077SN37K5    4.5        0    0.00       0.00
#
#       category_id  isBestSeller  boughtInLastMonth
# 0             104         False               2000
# 1             104         False               1000
# 2             104         False                300
# 3             104         False                400
# 4             104         False                400
# ...           ...           ...                ...
# 9995          110         False                  0
# 9996          110         False                  0
# 9997          110         False                  0
# 9998          110         False                  0
# 9999          110         False                  0
#
# [10000 rows x 12 columns]

# %%
solr.add([
    {
        "id": "doc_1",
        "title": "A test document"
    },
    {
        "id": "doc_2",
        "title": "The Bananas: Tasty or Dangerous?",
        "_doc": [
            { "id": "child_doc_1", "title": "peel"},
            { "id": "child_doc_2", "title": "seed"}
        ]
    }
])
# Out:
# '{\n  "responseHeader":{\n    "status":0,\n    "QTime":10\n  }\n}'

# %%
search_results = solr.search('bananas')
for r in search_results:
    print(r)
# Out:
# {'id': 'doc_2', 'title': ['The Bananas: Tasty or Dangerous?'], '_version_': 1793315208183152640}
